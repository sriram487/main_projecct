# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

# %%
DATA_PATH = r"C:\Users\sriram\Desktop\Main_Project\Project-data\data_1.json"

# %%
def load_data(data_path):
    """Loads training dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y

# %%
def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs
        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()

# %%
def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.
    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split
    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    return X_train, X_validation, X_test, y_train, y_validation, y_test

# %%
def build_model(input_shape):

    """Generates RNN-LSTM model
    :param input_shape (tuple): Shape of input set
    :return model: RNN-LSTM model
    """

    # build network topology
    model = keras.Sequential()

    # 2 LSTM layers
    model.add(keras.layers.LSTM(64, input_shape=input_shape, return_sequences=True))
    model.add(keras.layers.LSTM(64))

    # dense layer
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))

    # output layer
    model.add(keras.layers.Dense(4, activation='softmax'))

    return model

# %%
if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.2, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2]) # 130, 13
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=30)

    # plot accuracy/error for training and validation
    plot_history(history)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 216, 64)           19968
#
#  lstm_1 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 57,412
# Trainable params: 57,412
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 319/319 [==============================] - 90s 264ms/step - loss: 0.8196 - accuracy: 0.7199 - val_loss: 0.1686 - val_accuracy: 0.9706
# Epoch 2/30
# 319/319 [==============================] - 83s 260ms/step - loss: 0.1615 - accuracy: 0.9683 - val_loss: 0.0869 - val_accuracy: 0.9812
# Epoch 3/30
# 319/319 [==============================] - 83s 261ms/step - loss: 0.1023 - accuracy: 0.9786 - val_loss: 0.0679 - val_accuracy: 0.9843
# Epoch 4/30
# 319/319 [==============================] - 83s 262ms/step - loss: 0.0791 - accuracy: 0.9849 - val_loss: 0.0628 - val_accuracy: 0.9871
# Epoch 5/30
# 319/319 [==============================] - 83s 259ms/step - loss: 0.0735 - accuracy: 0.9850 - val_loss: 0.0617 - val_accuracy: 0.9863
# Epoch 6/30
# 319/319 [==============================] - 84s 262ms/step - loss: 0.0641 - accuracy: 0.9865 - val_loss: 0.0554 - val_accuracy: 0.9875
# Epoch 7/30
# 319/319 [==============================] - 84s 262ms/step - loss: 0.0583 - accuracy: 0.9872 - val_loss: 0.0532 - val_accuracy: 0.9886
# Epoch 8/30
# 319/319 [==============================] - 84s 265ms/step - loss: 0.0518 - accuracy: 0.9896 - val_loss: 0.0538 - val_accuracy: 0.9894
# Epoch 9/30
# 319/319 [==============================] - 82s 259ms/step - loss: 0.0669 - accuracy: 0.9858 - val_loss: 0.0517 - val_accuracy: 0.9906
# Epoch 10/30
# 319/319 [==============================] - 83s 260ms/step - loss: 0.0436 - accuracy: 0.9915 - val_loss: 0.0519 - val_accuracy: 0.9902
# Epoch 11/30
# 319/319 [==============================] - 87s 273ms/step - loss: 0.0472 - accuracy: 0.9900 - val_loss: 0.0463 - val_accuracy: 0.9910
# Epoch 12/30
# 319/319 [==============================] - 86s 269ms/step - loss: 0.0356 - accuracy: 0.9931 - val_loss: 0.0483 - val_accuracy: 0.9906
# Epoch 13/30
# 319/319 [==============================] - 84s 262ms/step - loss: 0.0372 - accuracy: 0.9927 - val_loss: 0.0509 - val_accuracy: 0.9910
# Epoch 14/30
# 319/319 [==============================] - 84s 264ms/step - loss: 0.0344 - accuracy: 0.9935 - val_loss: 0.0546 - val_accuracy: 0.9906
# Epoch 15/30
# 319/319 [==============================] - 84s 263ms/step - loss: 0.0379 - accuracy: 0.9924 - val_loss: 0.0538 - val_accuracy: 0.9894
# Epoch 16/30
# 319/319 [==============================] - 83s 261ms/step - loss: 0.0316 - accuracy: 0.9932 - val_loss: 0.0429 - val_accuracy: 0.9910
# Epoch 17/30
# 319/319 [==============================] - 84s 263ms/step - loss: 0.0321 - accuracy: 0.9935 - val_loss: 0.0423 - val_accuracy: 0.9918
# Epoch 18/30
# 319/319 [==============================] - 85s 266ms/step - loss: 0.0269 - accuracy: 0.9948 - val_loss: 0.0417 - val_accuracy: 0.9918
# Epoch 19/30
# 319/319 [==============================] - 85s 268ms/step - loss: 0.0315 - accuracy: 0.9937 - val_loss: 0.0471 - val_accuracy: 0.9898
# Epoch 20/30
# 319/319 [==============================] - 85s 265ms/step - loss: 0.0270 - accuracy: 0.9949 - val_loss: 0.0536 - val_accuracy: 0.9902
# Epoch 21/30
# 319/319 [==============================] - 85s 266ms/step - loss: 0.0363 - accuracy: 0.9920 - val_loss: 0.0411 - val_accuracy: 0.9910
# Epoch 22/30
# 319/319 [==============================] - 85s 268ms/step - loss: 0.0328 - accuracy: 0.9931 - val_loss: 0.0422 - val_accuracy: 0.9914
# Epoch 23/30
# 319/319 [==============================] - 85s 268ms/step - loss: 0.0270 - accuracy: 0.9946 - val_loss: 0.0321 - val_accuracy: 0.9937
# Epoch 24/30
# 319/319 [==============================] - 85s 267ms/step - loss: 0.0224 - accuracy: 0.9956 - val_loss: 0.0435 - val_accuracy: 0.9910
# Epoch 25/30
# 319/319 [==============================] - 86s 270ms/step - loss: 0.0315 - accuracy: 0.9937 - val_loss: 0.0332 - val_accuracy: 0.9925
# Epoch 26/30
# 319/319 [==============================] - 85s 267ms/step - loss: 0.0223 - accuracy: 0.9954 - val_loss: 0.0274 - val_accuracy: 0.9941
# Epoch 27/30
# 319/319 [==============================] - 86s 269ms/step - loss: 0.0737 - accuracy: 0.9833 - val_loss: 0.0322 - val_accuracy: 0.9906
# Epoch 28/30
# 319/319 [==============================] - 86s 270ms/step - loss: 0.0289 - accuracy: 0.9927 - val_loss: 0.0365 - val_accuracy: 0.9914
# Epoch 29/30
# 319/319 [==============================] - 86s 269ms/step - loss: 0.0378 - accuracy: 0.9921 - val_loss: 0.0361 - val_accuracy: 0.9894
# Epoch 30/30
# 319/319 [==============================] - 87s 273ms/step - loss: 0.0305 - accuracy: 0.9928 - val_loss: 0.0288 - val_accuracy: 0.9941
# 100/100 - 8s - loss: 0.0286 - accuracy: 0.9931 - 8s/epoch - 84ms/step
#
# Test accuracy: 0.9930969476699829

# %%
model.save("RNN_lstm.h5")

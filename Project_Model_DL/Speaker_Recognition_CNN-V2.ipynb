# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

# %%
DATA_PATH = r"C:\Users\sriram\Desktop\Main_Project\Project_Data\data_yt.json"

# %%
def load_data(data_path):
    """Loads training dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    
    return X, y

# %%
def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs
        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()

# %%
def prepare_datasets(test_size, validation_size):
    
    """Loads data and splits it into train, validation and test sets.
    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split
    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test

# %%
def build_model(input_shape):
    """Generates CNN model
    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    dropout_rate = .05
    regularazation = 0.001
   
    model.add(keras.layers.Conv2D(64, kernel_size=(3, 3), padding='same', 
                                  activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D(pool_size=(2, 2), strides=2))
    model.add(keras.layers.BatchNormalization())
    
    model.add(keras.layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu'))
    model.add(keras.layers.MaxPooling2D(pool_size=(2, 2), strides=2))
    model.add(keras.layers.BatchNormalization())
              
    model.add(keras.layers.Conv2D(16, kernel_size=(3, 3), padding='same', activation='relu'))
    model.add(keras.layers.MaxPooling2D(pool_size=(2, 2), strides=2))
    model.add(keras.layers.BatchNormalization())
              
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dropout(dropout_rate))
    model.add(keras.layers.Dense(8, activation='relu',
                kernel_regularizer=keras.regularizers.l2(regularazation)))
              
    model.add(keras.layers.Dropout(dropout_rate))
    model.add(keras.layers.Dense(10, activation='softmax'))
              
    return model

# %%
def predict(model, X, y):
    """Predict a single sample using the trained model
    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X)

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)

    print("Target: {}, Predicted label: {}".format(y, predicted_index))

# %%
if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    print(input_shape)
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=30)

    # plot accuracy/error for training and validation
    plot_history(history)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)    
    print('\nTest accuracy:', test_acc)

    # pick a sample to predict from the test set
    X_to_predict = X_test[100]
    y_to_predict = y_test[100]

    # predict sample
    predict(model, X_to_predict, y_to_predict)
# Out:
# (216, 13, 1)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 216, 13, 64)       640
#
#  max_pooling2d_4 (MaxPooling  (None, 108, 6, 64)       0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 108, 6, 64)       256
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 108, 6, 32)        18464
#
#  max_pooling2d_5 (MaxPooling  (None, 54, 3, 32)        0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 54, 3, 32)        128
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 54, 3, 16)         4624
#
#  max_pooling2d_6 (MaxPooling  (None, 27, 1, 16)        0
#  2D)
#
#  batch_normalization_5 (Batc  (None, 27, 1, 16)        64
#  hNormalization)
#
#  flatten (Flatten)           (None, 432)               0
#
#  dropout (Dropout)           (None, 432)               0
#
#  dense (Dense)               (None, 8)                 3464
#
#  dropout_1 (Dropout)         (None, 8)                 0
#
#  dense_1 (Dense)             (None, 10)                90
#
# =================================================================
# Total params: 27,730
# Trainable params: 27,506
# Non-trainable params: 224
# _________________________________________________________________
# Epoch 1/30
# 688/688 [==============================] - 83s 117ms/step - loss: 1.6304 - accuracy: 0.4052 - val_loss: 1.1202 - val_accuracy: 0.5802
# Epoch 2/30
# 688/688 [==============================] - 82s 119ms/step - loss: 1.0379 - accuracy: 0.5652 - val_loss: 0.7568 - val_accuracy: 0.6423
# Epoch 3/30
# 688/688 [==============================] - 84s 123ms/step - loss: 0.8353 - accuracy: 0.6056 - val_loss: 0.6509 - val_accuracy: 0.6489
# Epoch 4/30
# 688/688 [==============================] - 87s 126ms/step - loss: 0.7630 - accuracy: 0.6159 - val_loss: 0.6539 - val_accuracy: 0.6370
# Epoch 5/30
# 688/688 [==============================] - 88s 128ms/step - loss: 0.7030 - accuracy: 0.6334 - val_loss: 0.5611 - val_accuracy: 0.6565
# Epoch 6/30
# 688/688 [==============================] - 94s 137ms/step - loss: 0.6688 - accuracy: 0.6404 - val_loss: 0.5606 - val_accuracy: 0.6556
# Epoch 7/30
# 688/688 [==============================] - 95s 138ms/step - loss: 0.6470 - accuracy: 0.6494 - val_loss: 0.5698 - val_accuracy: 0.6449
# Epoch 8/30
# 688/688 [==============================] - 95s 137ms/step - loss: 0.6374 - accuracy: 0.6492 - val_loss: 0.5497 - val_accuracy: 0.6458
# Epoch 9/30
# 688/688 [==============================] - 96s 139ms/step - loss: 0.6217 - accuracy: 0.6511 - val_loss: 0.5377 - val_accuracy: 0.6481
# Epoch 10/30
# 688/688 [==============================] - 116s 169ms/step - loss: 0.6042 - accuracy: 0.6560 - val_loss: 0.5277 - val_accuracy: 0.6530
# Epoch 11/30
# 688/688 [==============================] - 121s 176ms/step - loss: 0.5968 - accuracy: 0.6569 - val_loss: 0.5425 - val_accuracy: 0.6450
# Epoch 12/30
# 688/688 [==============================] - 119s 172ms/step - loss: 0.5865 - accuracy: 0.6569 - val_loss: 0.5484 - val_accuracy: 0.6376
# Epoch 13/30
# 688/688 [==============================] - 121s 175ms/step - loss: 0.5806 - accuracy: 0.6607 - val_loss: 0.5322 - val_accuracy: 0.6398
# Epoch 14/30
# 688/688 [==============================] - 121s 176ms/step - loss: 0.5703 - accuracy: 0.6619 - val_loss: 0.5168 - val_accuracy: 0.6499
# Epoch 15/30
# 688/688 [==============================] - 119s 173ms/step - loss: 0.5642 - accuracy: 0.6662 - val_loss: 0.5649 - val_accuracy: 0.6398
# Epoch 16/30
# 688/688 [==============================] - 115s 168ms/step - loss: 0.5613 - accuracy: 0.6684 - val_loss: 0.5075 - val_accuracy: 0.6430
# Epoch 17/30
# 688/688 [==============================] - 116s 168ms/step - loss: 0.5532 - accuracy: 0.6725 - val_loss: 0.5137 - val_accuracy: 0.6452
# Epoch 18/30
# 688/688 [==============================] - 115s 167ms/step - loss: 0.5468 - accuracy: 0.6747 - val_loss: 0.5417 - val_accuracy: 0.6409
# Epoch 19/30
# 688/688 [==============================] - 118s 171ms/step - loss: 0.5467 - accuracy: 0.6734 - val_loss: 0.5164 - val_accuracy: 0.6429
# Epoch 20/30
# 688/688 [==============================] - 118s 172ms/step - loss: 0.5442 - accuracy: 0.6763 - val_loss: 0.5306 - val_accuracy: 0.6392
# Epoch 21/30
# 688/688 [==============================] - 115s 168ms/step - loss: 0.5369 - accuracy: 0.6768 - val_loss: 0.5058 - val_accuracy: 0.6478
# Epoch 22/30
# 688/688 [==============================] - 121s 175ms/step - loss: 0.5307 - accuracy: 0.6762 - val_loss: 0.5155 - val_accuracy: 0.6449
# Epoch 23/30
# 688/688 [==============================] - 118s 172ms/step - loss: 0.5304 - accuracy: 0.6756 - val_loss: 0.5011 - val_accuracy: 0.6438
# Epoch 24/30
# 688/688 [==============================] - 119s 172ms/step - loss: 0.5248 - accuracy: 0.6799 - val_loss: 0.5052 - val_accuracy: 0.6445
# Epoch 25/30
# 688/688 [==============================] - 121s 176ms/step - loss: 0.5228 - accuracy: 0.6823 - val_loss: 0.5130 - val_accuracy: 0.6367
# Epoch 26/30
# 688/688 [==============================] - 118s 172ms/step - loss: 0.5194 - accuracy: 0.6776 - val_loss: 0.5231 - val_accuracy: 0.6421
# Epoch 27/30
# 688/688 [==============================] - 117s 171ms/step - loss: 0.5177 - accuracy: 0.6801 - val_loss: 0.5013 - val_accuracy: 0.6432
# Epoch 28/30
# 688/688 [==============================] - 118s 172ms/step - loss: 0.5134 - accuracy: 0.6849 - val_loss: 0.5117 - val_accuracy: 0.6354
# Epoch 29/30
# 688/688 [==============================] - 117s 169ms/step - loss: 0.5138 - accuracy: 0.6808 - val_loss: 0.5450 - val_accuracy: 0.6265
# Epoch 30/30
# 688/688 [==============================] - 118s 172ms/step - loss: 0.5115 - accuracy: 0.6859 - val_loss: 0.4988 - val_accuracy: 0.6458
# 287/287 - 12s - loss: 0.5008 - accuracy: 0.6310 - 12s/epoch - 42ms/step
#
# Test accuracy: 0.6309705376625061
# 1/1 [==============================] - 3s 3s/step
# Target: 6, Predicted label: [6]

# %%
model.save("model_CNN_V2_10c.h5")

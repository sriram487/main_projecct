# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

# %%
DATA_PATH = r"C:\Users\sriram\Desktop\Main_Project\Project-data\data_1.json"

# %%
def load_data(data_path):
    """Loads training dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    
    return X, y

# %%
def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs
        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()

# %%
def prepare_datasets(test_size, validation_size):
    
    """Loads data and splits it into train, validation and test sets.
    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split
    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test

# %%
def build_model(input_shape):
    """Generates CNN model
    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(32, (2, 2), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # flatten output and feed it into dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))

    # output layer
    model.add(keras.layers.Dense(4, activation='softmax'))

    return model

# %%
def predict(model, X, y):
    """Predict a single sample using the trained model
    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X)

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)

    print("Target: {}, Predicted label: {}".format(y, predicted_index))

# %%
if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    print(input_shape)
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=30)

    # plot accuracy/error for training and validation
    plot_history(history)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)    
    print('\nTest accuracy:', test_acc)

    # pick a sample to predict from the test set
    X_to_predict = X_test[100]
    y_to_predict = y_test[100]

    # predict sample
    predict(model, X_to_predict, y_to_predict)
# Out:
# (216, 13, 1)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 214, 11, 32)       320
#
#  max_pooling2d (MaxPooling2D  (None, 107, 6, 32)       0
#  )
#
#  batch_normalization (BatchN  (None, 107, 6, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 105, 4, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 53, 2, 32)        0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 53, 2, 32)        128
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 52, 1, 32)         4128
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 1, 32)        0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 26, 1, 32)        128
#  hNormalization)
#
#  flatten (Flatten)           (None, 832)               0
#
#  dense (Dense)               (None, 64)                53312
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 67,652
# Trainable params: 67,460
# Non-trainable params: 192
# _________________________________________________________________
# Epoch 1/30
# 299/299 [==============================] - 23s 69ms/step - loss: 0.4839 - accuracy: 0.8273 - val_loss: 0.1962 - val_accuracy: 0.9573
# Epoch 2/30
# 299/299 [==============================] - 21s 69ms/step - loss: 0.1192 - accuracy: 0.9679 - val_loss: 0.0900 - val_accuracy: 0.9858
# Epoch 3/30
# 299/299 [==============================] - 21s 70ms/step - loss: 0.0816 - accuracy: 0.9795 - val_loss: 0.0608 - val_accuracy: 0.9900
# Epoch 4/30
# 299/299 [==============================] - 21s 71ms/step - loss: 0.0610 - accuracy: 0.9847 - val_loss: 0.0592 - val_accuracy: 0.9916
# Epoch 5/30
# 299/299 [==============================] - 21s 70ms/step - loss: 0.0446 - accuracy: 0.9888 - val_loss: 0.0434 - val_accuracy: 0.9929
# Epoch 6/30
# 299/299 [==============================] - 21s 71ms/step - loss: 0.0352 - accuracy: 0.9913 - val_loss: 0.0384 - val_accuracy: 0.9925
# Epoch 7/30
# 299/299 [==============================] - 21s 71ms/step - loss: 0.0344 - accuracy: 0.9912 - val_loss: 0.0240 - val_accuracy: 0.9921
# Epoch 8/30
# 299/299 [==============================] - 21s 72ms/step - loss: 0.0276 - accuracy: 0.9929 - val_loss: 0.0253 - val_accuracy: 0.9933
# Epoch 9/30
# 299/299 [==============================] - 22s 72ms/step - loss: 0.0236 - accuracy: 0.9938 - val_loss: 0.0194 - val_accuracy: 0.9958
# Epoch 10/30
# 299/299 [==============================] - 22s 72ms/step - loss: 0.0233 - accuracy: 0.9941 - val_loss: 0.0437 - val_accuracy: 0.9933
# Epoch 11/30
# 299/299 [==============================] - 22s 73ms/step - loss: 0.0195 - accuracy: 0.9950 - val_loss: 0.0174 - val_accuracy: 0.9967
# Epoch 12/30
# 299/299 [==============================] - 21s 71ms/step - loss: 0.0156 - accuracy: 0.9958 - val_loss: 0.0173 - val_accuracy: 0.9967
# Epoch 13/30
# 299/299 [==============================] - 21s 71ms/step - loss: 0.0174 - accuracy: 0.9948 - val_loss: 0.0179 - val_accuracy: 0.9971
# Epoch 14/30
# 299/299 [==============================] - 21s 71ms/step - loss: 0.0139 - accuracy: 0.9957 - val_loss: 0.0173 - val_accuracy: 0.9962
# Epoch 15/30
# 299/299 [==============================] - 21s 72ms/step - loss: 0.0134 - accuracy: 0.9974 - val_loss: 0.0161 - val_accuracy: 0.9967
# Epoch 16/30
# 299/299 [==============================] - 21s 71ms/step - loss: 0.0111 - accuracy: 0.9975 - val_loss: 0.0184 - val_accuracy: 0.9946
# Epoch 17/30
# 299/299 [==============================] - 21s 71ms/step - loss: 0.0114 - accuracy: 0.9965 - val_loss: 0.0185 - val_accuracy: 0.9954
# Epoch 18/30
# 299/299 [==============================] - 22s 72ms/step - loss: 0.0096 - accuracy: 0.9974 - val_loss: 0.0271 - val_accuracy: 0.9937
# Epoch 19/30
# 299/299 [==============================] - 22s 72ms/step - loss: 0.0117 - accuracy: 0.9961 - val_loss: 0.0246 - val_accuracy: 0.9946
# Epoch 20/30
# 299/299 [==============================] - 21s 72ms/step - loss: 0.0081 - accuracy: 0.9976 - val_loss: 0.0203 - val_accuracy: 0.9941
# Epoch 21/30
# 299/299 [==============================] - 22s 73ms/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.0564 - val_accuracy: 0.9941
# Epoch 22/30
# 299/299 [==============================] - 21s 71ms/step - loss: 0.0055 - accuracy: 0.9985 - val_loss: 0.0154 - val_accuracy: 0.9967
# Epoch 23/30
# 299/299 [==============================] - 21s 72ms/step - loss: 0.0070 - accuracy: 0.9982 - val_loss: 0.0164 - val_accuracy: 0.9962
# Epoch 24/30
# 299/299 [==============================] - 22s 73ms/step - loss: 0.0067 - accuracy: 0.9978 - val_loss: 0.0205 - val_accuracy: 0.9954
# Epoch 25/30
# 299/299 [==============================] - 21s 72ms/step - loss: 0.0047 - accuracy: 0.9987 - val_loss: 0.0164 - val_accuracy: 0.9971
# Epoch 26/30
# 299/299 [==============================] - 22s 72ms/step - loss: 0.0067 - accuracy: 0.9981 - val_loss: 0.0156 - val_accuracy: 0.9967
# Epoch 27/30
# 299/299 [==============================] - 22s 75ms/step - loss: 0.0047 - accuracy: 0.9983 - val_loss: 0.0192 - val_accuracy: 0.9958
# Epoch 28/30
# 299/299 [==============================] - 22s 72ms/step - loss: 0.0068 - accuracy: 0.9981 - val_loss: 0.0175 - val_accuracy: 0.9962
# Epoch 29/30
# 299/299 [==============================] - 22s 73ms/step - loss: 0.0039 - accuracy: 0.9985 - val_loss: 0.0184 - val_accuracy: 0.9967
# Epoch 30/30
# 299/299 [==============================] - 22s 73ms/step - loss: 0.0061 - accuracy: 0.9979 - val_loss: 0.0240 - val_accuracy: 0.9941
# 125/125 - 2s - loss: 0.0344 - accuracy: 0.9937 - 2s/epoch - 18ms/step
#
# Test accuracy: 0.9937248826026917
# 1/1 [==============================] - 0s 357ms/step
# Target: 1, Predicted label: [1]

# %%
model.save("model_CNN_10c.h5")

# %%
Test_Data_path = r""

with open(data_path, "r") as fp:
    data = json.load(fp)

X_test1 = np.array(data["mfcc"])
y_test1 = np.array(data["labels"])

y_predited = []

for i in X_test:
    i = i[np.newaxis, ...]
    prediction = model.predict(i)
    predicted_index = np.argmax(prediction, axis=1)
    y_predicted.append(prediction_index[0])
    
for i,j in y_predict, y_test1:
    print(i + " " + j)
